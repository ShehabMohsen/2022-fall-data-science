# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
df = pd.read_csv('./data/listings.csv')
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 

select_condition1 = df['price'] < 100

df_cheap = df[select_condition]

print("Number of rows and columns:", df_cheap.shape)
print("\nFirst five rows:")
df_cheap.head()
# Out:
# Number of rows and columns: (22778, 16)
#
# First five rows:
#      id                                               name  host_id  \
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 4  5178                   Large Furnished Room Near B'way　     8967
# 5  5203                 Cozy Clean Guest Room - Family Apt     7490
# 8  5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 5    MaryEllen           Manhattan     Upper West Side  40.80178  -73.96723
# 8       Laurie            Brooklyn         South Slope  40.66829  -73.98779
#
# ...

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.

select_condition2 = df['neighbourhood_group'] == 'Brooklyn'

df_bk = df[ select_condition2 ]

print('Number of rows and columns:', df_bk.shape)
print('\nFirst five rows:')
df_bk.head()
# Out:
# Number of rows and columns: (18632, 16)
#
# First five rows:
#       id                                               name  host_id  \
# 1   3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2   5121                                    BlissArtsSpace!     7356
# 3   5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 8   5803     Lovely Room 1, Garden, Best Area, Legal rental     9744
# 11  6848                   Only 2 stops to Manhattan studio    15991
#
#         host_name neighbourhood_group       neighbourhood  latitude  \
# 1     LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 2           Garon            Brooklyn  Bedford-Stuyvesant  40.68688
# 3         Rebecca            Brooklyn         Sunset Park  40.66120
# 8          Laurie            Brooklyn         South Slope  40.66829
# 11  Allen & Irina            Brooklyn        Williamsburg  40.70837
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

df_cheap_bk = df [ select_condition1 & select_condition2]

print('Number of listings there are in Broolyin with a price less than 100:')
df_cheap_bk.shape[0]
# Out:
# Number of listings there are in Broolyin with a price less than 100:
# 10473

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.


host_names = ['Michael', 'David', 'John', 'Daniel']

condition = df['host_name'].isin(host_names)

df_host_names = df[ condition ]

df_host_names.head()
# Out:
#         id                                               name  host_id  \
# 52   16595  LOFT HAVEN ~ Six Windows ~ Bricks ~ Plants ~ Q...    64522
# 201  61747              Cozy,  Brooklyn, Prospect Park Studio   299370
# 209  62903  Beautiful modern studio apartment in heart of NYC   306605
# 220  64015                       Prime East Village 1 Bedroom   146944
# 260  74073       Food & Music Dream Apartment in Williamsburg   211877
#
#     host_name neighbourhood_group              neighbourhood  latitude  \
# 52     Daniel            Brooklyn               Williamsburg  40.70933
# 201     David            Brooklyn  Prospect-Lefferts Gardens  40.65979
# 209    Daniel           Manhattan                    Chelsea  40.74238
# 220     David           Manhattan               East Village  40.72807
# 260    Daniel            Brooklyn               Williamsburg  40.71113
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before. 

# select condition
price_condition =  df['neighbourhood'] == 'Williamsburg' 

# create a new column and set its value based on the select condition
df['adjusted_price'] = np.where(price_condition, df['price']+100, df['price'])

# display rows where neighbourhood is Williamsburg
df[ df['neighbourhood']=='Williamsburg'].head()
# Out:
#        id                              name  host_id      host_name  \
# 11   6848  Only 2 stops to Manhattan studio    15991  Allen & Irina
# 15   7801  Sweet and Spacious Brooklyn Loft    21207          Chaya
# 35  14290        * ORIGINAL BROOKLYN LOFT *    56104          James
# 38  14377  Williamsburg 1 bedroom Apartment    56512         Joanna
# 42  15385             Very, very cozy place    60252       Cristina
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 11            Brooklyn  Williamsburg  40.70837  -73.95352  Entire home/apt
# 15            Brooklyn  Williamsburg  40.71842  -73.95718  Entire home/apt
# 35            Brooklyn  Williamsburg  40.70420  -73.93560  Entire home/apt
# 38            Brooklyn  Williamsburg  40.70881  -73.95930  Entire home/apt
# 42            Brooklyn  Williamsburg  40.71185  -73.96204     Private room
#
#     price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

room_types = ["Shared room", "Private room"]

room_condition = df['room_type'].isin(room_types)

print('all types count', df.room_type.value_counts().sum())

df[room_condition].room_type.value_counts() / df.room_type.value_counts().sum()
# Out:
# all types count 46527
# Private room    0.454446
# Shared room     0.021213
# Name: room_type, dtype: float64

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.


gb = df.groupby('neighbourhood_group')

gb.neighbourhood_group.count()
# Out:
# neighbourhood_group
# Bronx             1183
# Brooklyn         18632
# Manhattan        20580
# Queens            5791
# Staten Island      341
# Name: neighbourhood_group, dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 

gb_price = df.groupby('neighbourhood_group')
gb_price['price'].mean()
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 

gb_price['price'].agg(['min', 'max'])
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.

# in double grouping, order matters
groupby_cols = ['neighbourhood_group', 'room_type']

# grouping data using the cols of interest
gb_room_type = df.groupby(groupby_cols)

# extracting the mean from the price column
gb_room_type['price'].mean()
# Out:
# neighbourhood_group  room_type
# Bronx                Entire home/apt    138.004819
#                      Private room        68.419668
#                      Shared room         66.391304
# Brooklyn             Entire home/apt    171.587687
#                      Hotel room         147.300000
#                      Private room        71.291189
#                      Shared room         57.870091
# Manhattan            Entire home/apt    231.335572
#                      Hotel room         292.515670
#                      Private room       128.277069
#                      Shared room        111.735084
# Queens               Entire home/apt    150.168900
#                      Hotel room         139.058824
#                      Private room        69.972564
#                      Shared room         89.891892
# Staten Island        Entire home/apt    151.720930
#                      Private room        70.312883
#                      Shared room         46.000000
# ...

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.

gb_room_type['price'].agg(['min', 'max', 'mean', 'median', 'std'])
# Out:
#                                      min    max        mean  median  \
# neighbourhood_group room_type
# Bronx               Entire home/apt   25   1404  138.004819   103.0
#                     Private room      16    700   68.419668    55.0
#                     Shared room       20    800   66.391304    44.0
# Brooklyn            Entire home/apt   20  10000  171.587687   135.0
#                     Hotel room         0    399  147.300000   129.0
#                     Private room      10   2500   71.291189    60.0
#                     Shared room       15   1500   57.870091    36.0
# Manhattan           Entire home/apt    0  10000  231.335572   165.0
#                     Hotel room         0   2211  292.515670   210.0
#                     Private room      10  10000  128.277069    80.0
#                     Shared room       10  10000  111.735084    60.0
# Queens              Entire home/apt   10  10000  150.168900   115.0
# ...

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load `prices.csv`

df_prices = pd.read_csv('./data/prices.csv')
df_prices
# Out:
#   neighbourhood_group   mean_price
# 0               Bronx    92.751479
# 1            Brooklyn   120.225258
# 2           Manhattan   191.880466
# 3              Queens    99.754965
# 4       Staten Island   110.947214

# %%
# 2. Load `n_listings.csv`

df_listings = pd.read_csv('./data/n_listings.csv', sep=';')
df_listings
# Out:
#   neighbourhood_group  n_listings
# 0               Bronx        1183
# 1            Brooklyn       18632
# 2           Manhattan       20580
# 3          LongIsland        4121

# %%
# 3. Do join that keeps all the records for each table.

# removing the how='outer' from the method parameter will omit rows that don't exist in at least one data_frame
merged_df = pd.merge(df_listings, df_prices, on='neighbourhood_group', how='outer')
merged_df
# Out:
#   neighbourhood_group  n_listings   mean_price
# 0               Bronx      1183.0    92.751479
# 1            Brooklyn     18632.0   120.225258
# 2           Manhattan     20580.0   191.880466
# 3          LongIsland      4121.0          NaN
# 4              Queens         NaN    99.754965
# 5       Staten Island         NaN   110.947214

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
#  1. Who was won Album of the Year in 2016?

df_grammys = pd.read_csv('./data/grammys.csv')

category_condition = df_grammys['category'] == 'Album of the Year'
year_condition = df_grammys['year'] == 2016
is_won = df_grammys['winner']==True

df_grammys[category_condition & year_condition & is_won]['workers']
# Out:
# 5505    Taylor Swift (artist/producer), Jack Antonoff ...
# Name: workers, dtype: object

# %%
# 2. Who won Best Rap Album in 2009?

category_condition2 = df_grammys['category']=='Best Rap Album' 
year_condition2 = df_grammys['year'] == 2009
is_won = df_grammys['winner']==True

df_grammys[category_condition2 & year_condition2 & is_won]['workers']
# Out:
# 4396    Lil' Wayne
# Name: workers, dtype: object

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

kendrick = df_grammys['workers'] == "Kendrick Lamar"
is_won = df_grammys['winner']==True

print(f'Kendrick Lamar was nominated for {len(df_grammys[kendrick])} awards,') 
print(f'and won {len(df_grammys[is_won & kendrick])}')
# Out:
# Kendrick Lamar was nominated for 6 awards,
# and won 4
